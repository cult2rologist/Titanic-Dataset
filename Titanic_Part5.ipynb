# %% [markdown]
# # __Titanic dataset exploratory analysis__
#
# ##### With this project, I want to learn data analysis approaches using Python and special libraries such as:
# * Pandas
# * Seaborn
# * Matplotlib.pyplot
#
#
# ##### There won't be any specific questions I want to ask this data before getting started. I will explore as many questions as I can during the process. Some of the research may be redundant and not practically useful for a real-case data analysis. However, primarily, this project focuses on working with data visualization tools. Throughout the process, I will enhance my ability to understand and work with data in Python.
#
#
# ### Part #5: Final exploration

# %% [markdown]
# #### __This is the last time we're bringing in our libraries__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * As usual, we start from reading our dataset using Pandas
# * Cheking result using .head() function

# %%
titanic = pd.read_csv('Titanic_cleaned.csv')
titanic.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       No       3
# 1            2      Yes       1
# 2            3      Yes       3
# 3            4      Yes       1
# 4            5       No       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### __Let's check how the survival rates vary from different viewpoints__
# * The first plot illustrates the survival rates among different passenger classes

# %%
# First, we need to convert the 'Survived' column back to Boolean logic
titanic['Survived'] = titanic['Survived'].map({'Yes':1, 'No':0})

sns.catplot(data=titanic, x='Pclass', y='Survived', kind='point')
plt.title('Survival Rates Across Passenger Classes')
# Out:
# Text(0.5, 1.0, 'Survival Rates Across Passenger Classes')

# %% [markdown]
# * The second plot displays the relationship between age and survival rate, employing a linear regression model

# %%
sns.lmplot(data=titanic, x='Age', y='Survived', palette='colorblind')
plt.title('Age and Survival Rate: Linear Regression')
# Out:
# Text(0.5, 1.0, 'Age and Survival Rate: Linear Regression')

# %% [markdown]
# * The third plot illustrates the connection between age, survival, and passenger class, with a linear regression model

# %%
sns.lmplot(data=titanic, x='Age', y='Survived', hue='Pclass', palette='colorblind')
plt.title('Age, Survival, and Passenger Class Relationship')
# Out:
# Text(0.5, 1.0, 'Age, Survival, and Passenger Class Relationship')

# %% [markdown]
# * The fourth plot demonstrates how age, survival, and gender are interrelated, utilizing a linear regression model

# %%
sns.lmplot(data=titanic, x='Age', y='Survived', hue='Sex', palette='colorblind')
plt.title('Age, Survival, and Gender Interrelation')
# Out:
# Text(0.5, 1.0, 'Age, Survival, and Gender Interrelation')

# %% [markdown]
# #### __In conclusion,__
# #### Our comprehensive analysis of the Titanic dataset revealed several interesting insights. We observed a direct correlation between the count of children on board and the overall number of passengers in each class. Additionally, among the adult passengers, the number of those without children was significantly higher than those traveling with family. Exploring cabin data, we examined the distribution across passenger classes, shedding light on the ship's spatial layout. Furthermore, we delved into the survival rate across classes, noting a strong correlation between age and survival. This correlation influenced different passenger classes in distinct ways. Lastly, our study highlighted the tragic loss of many men and the successful rescue of numerous women on that fateful day. These findings provide a nuanced understanding of the Titanic's demographics and shed light on the various factors influencing survival outcomes.

# %% [markdown]
# #### __With this project,__
# #### my primary goal was to delve into the realm of data visualization using Python tools. Throughout the journey, I aimed to enhance my proficiency in understanding and manipulating data, with a particular emphasis on leveraging visualization techniques. By working on this project, I successfully achieved my objectives, gaining valuable insights into data analysis, interpretation, and presentation. The hands-on experience with various visualization libraries has not only broadened my skill set but also equipped me with the practical knowledge needed for future data-centric endeavors. This project has been a significant stepping stone in my continuous learning journey, providing a solid foundation for more advanced explorations in the field of data analysis.
